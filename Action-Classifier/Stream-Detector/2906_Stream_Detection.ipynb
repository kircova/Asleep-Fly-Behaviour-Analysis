# %% [markdown]
# ## Imports and Lib Installs

# %%
# !pip install remotezip tqdm opencv-python einops
# Out:
# Collecting remotezip
#   Downloading remotezip-0.12.1.tar.gz (7.5 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.65.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.7.0.72)
# Collecting einops
#   Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from remotezip) (2.27.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from remotezip) (0.8.10)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.22.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (3.4)
# Building wheels for collected packages: remotezip
#   Building wheel for remotezip (setup.py) ... done
#   Created wheel for remotezip: filename=remotezip-0.12.1-py3-none-any.whl size=7933 sha256=822754e4c0a031e663c7a0d875a0a6bf7a1bb1bba4309e97beb0e9af6b258fdc
#   Stored in directory: /root/.cache/pip/wheels/fc/76/04/beed1a6df4eb7430ee13c3900746edd517e5e597298d1f73f3
# Successfully built remotezip
# Installing collected packages: einops, remotezip
# Successfully installed einops-0.6.1 remotezip-0.12.1

# %%
# !pip install seaborn
# !pip install keras
# !pip install remotezip
# !pip install collection
# !pip install picklable-itertools
# !pip install pathlib
# !pip install random2
# !pip install tensorflow
# !pip install remotezip tqdm opencv-python einops
# !pip install -U statsmodels
# !pip install remotezip tqdm opencv-python==4.5.2.52 opencv-python-headless==4.5.2.52 tf-models-official
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.10/dist-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.22.4)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.10/dist-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /usr/local/lib/python3.10/dist-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.25->seaborn) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.12.0)
# Requirement already satisfied: remotezip in /usr/local/lib/python3.10/dist-packages (0.12.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from remotezip) (2.27.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from remotezip) (0.8.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (3.4)
# Collecting collection
#   Downloading collection-0.1.6.tar.gz (5.0 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: collection
#   Building wheel for collection (setup.py) ... done
#   Created wheel for collection: filename=collection-0.1.6-py3-none-any.whl size=5098 sha256=92c14395f9889dfb3ab070cb05d63b86e9b018513450830806cdc27901bbb20c
#   Stored in directory: /root/.cache/pip/wheels/a5/70/eb/1d28795e9384ab3b9be6359bdde9e1652f6e7dab9d26844f70
# Successfully built collection
# Installing collected packages: collection
# Successfully installed collection-0.1.6
# Collecting picklable-itertools
#   Downloading picklable-itertools-0.1.1.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from picklable-itertools) (1.16.0)
# Building wheels for collected packages: picklable-itertools
#   Building wheel for picklable-itertools (setup.py) ... done
#   Created wheel for picklable-itertools: filename=picklable_itertools-0.1.1-py3-none-any.whl size=15571 sha256=5af462a5c531c4b29d03ecf1390828c76d1c07df7a658dc303d95418c8a2463f
#   Stored in directory: /root/.cache/pip/wheels/58/19/34/8fc5b4c7d645b73b2e61f5b48699cefda12a903666e5170b84
# Successfully built picklable-itertools
# Installing collected packages: picklable-itertools
# Successfully installed picklable-itertools-0.1.1
# Requirement already satisfied: pathlib in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Collecting random2
#   Downloading random2-1.0.1.zip (21 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: random2
#   Building wheel for random2 (setup.py) ... done
#   Created wheel for random2: filename=random2-1.0.1-py3-none-any.whl size=12042 sha256=6bd002f681fd2379c19f93f06ef820ce040d1ca587cbd91294d84e1111ebf2d5
#   Stored in directory: /root/.cache/pip/wheels/61/1f/84/8713326a151c1638e7a00202e4074b46e839d22b7d22f8400f
# Successfully built random2
# Installing collected packages: random2
# Successfully installed random2-1.0.1
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.56.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.4.10)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (16.0.0)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.22.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.6.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.32.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.40.0)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow) (0.2.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow) (1.10.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (3.4.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.27.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow) (2.3.6)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow) (3.2.2)
# Requirement already satisfied: remotezip in /usr/local/lib/python3.10/dist-packages (0.12.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.65.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.7.0.72)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (0.6.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from remotezip) (2.27.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from remotezip) (0.8.10)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.22.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (3.4)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (0.13.5)
# Collecting statsmodels
#   Downloading statsmodels-0.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 66.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (1.22.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (1.10.1)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (1.5.3)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0->statsmodels) (2022.7.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Installing collected packages: statsmodels
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.13.5
#     Uninstalling statsmodels-0.13.5:
#       Successfully uninstalled statsmodels-0.13.5
# Successfully installed statsmodels-0.14.0
# Requirement already satisfied: remotezip in /usr/local/lib/python3.10/dist-packages (0.12.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.65.0)
# ERROR: Could not find a version that satisfies the requirement opencv-python==4.5.2.52 (from versions: 3.4.0.14, 3.4.10.37, 3.4.11.39, 3.4.11.41, 3.4.11.43, 3.4.11.45, 3.4.13.47, 3.4.15.55, 3.4.16.57, 3.4.16.59, 3.4.17.61, 3.4.17.63, 3.4.18.65, 4.3.0.38, 4.4.0.40, 4.4.0.42, 4.4.0.44, 4.4.0.46, 4.5.1.48, 4.5.3.56, 4.5.4.58, 4.5.4.60, 4.5.5.62, 4.5.5.64, 4.6.0.66, 4.7.0.68, 4.7.0.72)
# ERROR: No matching distribution found for opencv-python==4.5.2.52

# %%
# !pip install tf-models-official
# Out:
# Collecting tf-models-official
#   Downloading tf_models_official-2.12.0-py2.py3-none-any.whl (2.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 28.9 MB/s eta 0:00:00
# Requirement already satisfied: Cython in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (0.29.35)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (8.4.0)
# Requirement already satisfied: gin-config in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (0.5.0)
# Requirement already satisfied: google-api-python-client>=1.6.7 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (2.84.0)
# Collecting immutabledict (from tf-models-official)
#   Downloading immutabledict-2.2.4-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: kaggle>=1.3.9 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (1.5.13)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (3.7.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (1.22.4)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (4.1.3)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (4.7.0.72)
# Requirement already satisfied: pandas>=0.22.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (1.5.3)
# Requirement already satisfied: psutil>=5.4.3 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (5.9.5)
# Requirement already satisfied: py-cpuinfo>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (9.0.0)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (2.0.6)
# Collecting pyyaml<6.0,>=5.1 (from tf-models-official)
#   Downloading PyYAML-5.4.1.tar.gz (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.1/175.1 kB 18.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting sacrebleu (from tf-models-official)
#   Downloading sacrebleu-2.3.1-py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (1.10.1)
# Collecting sentencepiece (from tf-models-official)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 69.1 MB/s eta 0:00:00
# Collecting seqeval (from tf-models-official)
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (1.16.0)
# Collecting tensorflow-addons (from tf-models-official)
#   Downloading tensorflow_addons-0.20.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (591 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 591.0/591.0 kB 52.8 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (4.9.2)
# Requirement already satisfied: tensorflow-hub>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (0.13.0)
# Collecting tensorflow-model-optimization>=0.4.1 (from tf-models-official)
#   Downloading tensorflow_model_optimization-0.7.5-py2.py3-none-any.whl (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.2/241.2 kB 29.4 MB/s eta 0:00:00
# Collecting tensorflow-text~=2.12.0 (from tf-models-official)
#   Downloading tensorflow_text-2.12.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 89.4 MB/s eta 0:00:00
# Requirement already satisfied: tensorflow~=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (2.12.0)
# Requirement already satisfied: tf-slim>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tf-models-official) (1.1.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official) (0.21.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official) (2.17.3)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official) (0.1.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official) (2.11.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.6.7->tf-models-official) (4.1.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official) (2023.5.7)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official) (2.27.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official) (4.65.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official) (8.0.1)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle>=1.3.9->tf-models-official) (1.26.16)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.22.0->tf-models-official) (2022.7.1)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official) (1.56.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official) (3.8.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official) (0.4.10)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official) (16.0.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official) (67.7.2)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official) (4.6.3)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow~=2.12.0->tf-models-official) (0.32.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow-model-optimization>=0.4.1->tf-models-official) (0.1.8)
# Collecting numpy>=1.20 (from tf-models-official)
#   Downloading numpy-1.23.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 62.6 MB/s eta 0:00:00
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tf-models-official) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tf-models-official) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tf-models-official) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tf-models-official) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->tf-models-official) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official) (0.5.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official) (0.3.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client->tf-models-official) (4.9)
# Collecting portalocker (from sacrebleu->tf-models-official)
#   Downloading portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from sacrebleu->tf-models-official) (2022.10.31)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.10/dist-packages (from sacrebleu->tf-models-official) (0.8.10)
# Collecting colorama (from sacrebleu->tf-models-official)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from sacrebleu->tf-models-official) (4.9.2)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval->tf-models-official) (1.2.2)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons->tf-models-official)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: array-record in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official) (0.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official) (8.1.3)
# Requirement already satisfied: etils[enp,epath]>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official) (1.3.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official) (2.3)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official) (1.13.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->tf-models-official) (0.10.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow~=2.12.0->tf-models-official) (0.40.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets->tf-models-official) (5.12.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[enp,epath]>=0.9.0->tensorflow-datasets->tf-models-official) (3.15.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.6.7->tf-models-official) (1.59.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.6.7->tf-models-official) (5.3.1)
# Requirement already satisfied: ml-dtypes>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jax>=0.3.15->tensorflow~=2.12.0->tf-models-official) (0.2.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle>=1.3.9->tf-models-official) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle>=1.3.9->tf-models-official) (3.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval->tf-models-official) (3.1.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official) (3.4.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official) (2.3.6)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle>=1.3.9->tf-models-official) (1.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official) (2.1.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow~=2.12.0->tf-models-official) (3.2.2)
# Building wheels for collected packages: pyyaml, seqeval
#   Building wheel for pyyaml (pyproject.toml) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.4.1-cp310-cp310-linux_x86_64.whl size=45658 sha256=5397e393849998d3d0fc6ccaf70040f93a7e6e4c30de1821046ed8c7172a5f4f
#   Stored in directory: /root/.cache/pip/wheels/c7/0d/22/696ee92245ad710f506eee79bb05c740d8abccd3ecdb778683
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16165 sha256=b2462436e1851a060b1cbbfba39fa578dda8833d9371df9608a34a3eae109f9b
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built pyyaml seqeval
# Installing collected packages: sentencepiece, typeguard, pyyaml, portalocker, numpy, immutabledict, colorama, tensorflow-model-optimization, tensorflow-addons, sacrebleu, seqeval, tensorflow-text, tf-models-official
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 6.0
#     Uninstalling PyYAML-6.0:
#       Successfully uninstalled PyYAML-6.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
# Successfully installed colorama-0.4.6 immutabledict-2.2.4 numpy-1.23.5 portalocker-2.7.0 pyyaml-5.4.1 sacrebleu-2.3.1 sentencepiece-0.1.99 seqeval-1.2.2 tensorflow-addons-0.20.0 tensorflow-model-optimization-0.7.5 tensorflow-text-2.12.1 tf-models-official-2.12.0 typeguard-2.13.3

# %%
# !pip install remotezip tqdm opencv-python
# !pip install -q git+https://github.com/tensorflow/docs
# Out:
# Requirement already satisfied: remotezip in /usr/local/lib/python3.10/dist-packages (0.12.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.65.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.7.0.72)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from remotezip) (2.27.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from remotezip) (0.8.10)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.23.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->remotezip) (3.4)
#   Preparing metadata (setup.py) ... done
#   Building wheel for tensorflow-docs (setup.py) ... done

# %%
import tqdm
import random
import pathlib
import itertools
import collections

import cv2
import numpy as np
import remotezip as rz
import seaborn as sns
import matplotlib.pyplot as plt

import keras
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy

# Import the MoViNet model from TensorFlow Models (tf-models-official) for the MoViNet model
from official.projects.movinet.modeling import movinet
from official.projects.movinet.modeling import movinet_model

# %% [markdown]
# # Video Download

# %%
URL = 'https://storage.googleapis.com/29-06-fly-project/Action_v6.zip'

# %%
def list_files_from_zip_url(zip_url):
  """ List the files in each class of the dataset given a URL with the zip file.

    Args:
      zip_url: A URL from which the files can be extracted from.

    Returns:
      List of files in each of the classes.
  """
  files = []
  with rz.RemoteZip(zip_url) as zip:
    for zip_info in zip.infolist():
      if zip_info.filename[0:3] != "__M":
        files.append(zip_info.filename)
  return files

# %%
files = list_files_from_zip_url(URL)
files = [f for f in files if f.endswith('.avi')]
(files)
# Out:
# ['Action_v6/v_Grooming_g01_c326.avi',
#  'Action_v6/v_Pumping_g01_c119.avi',
#  'Action_v6/v_Grooming_g01_c332.avi',
#  'Action_v6/v_Pumping_g01_c125.avi',
#  'Action_v6/v_Pumping_g01_c8.avi',
#  'Action_v6/v_Pumping_g01_c131.avi',
#  'Action_v6/v_Feeding_g01_c249.avi',
#  'Action_v6/v_Feeding_g01_c261.avi',
#  'Action_v6/v_Feeding_g01_c275.avi',
#  'Action_v6/v_Grooming_g01_c124.avi',
#  'Action_v6/v_Grooming_g01_c130.avi',
#  'Action_v6/v_Pumping_g01_c327.avi',
#  'Action_v6/v_Grooming_g01_c118.avi',
#  'Action_v6/v_Grooming_g01_c36.avi',
#  'Action_v6/v_Grooming_g01_c22.avi',
#  'Action_v6/v_Pumping_g01_c333.avi',
#  'Action_v6/v_Feeding_g01_c329.avi',
#  'Action_v6/v_Feeding_g01_c315.avi',
#  'Action_v6/v_Pumping_g01_c290.avi',
#  'Action_v6/v_Feeding_g01_c96.avi',
#  'Action_v6/v_Feeding_g01_c82.avi',
#  'Action_v6/v_Feeding_g01_c301.avi',
#  'Action_v6/v_Pumping_g01_c284.avi',
#  'Action_v6/v_Feeding_g01_c69.avi',
#  'Action_v6/v_Pumping_g01_c253.avi',
#  'Action_v6/v_Feeding_g01_c55.avi',
#  'Action_v6/v_Feeding_g01_c41.avi',
#  'Action_v6/v_Pumping_g01_c247.avi',
#  'Action_v6/v_Pumping_g01_c50.avi',
#  'Action_v6/v_Grooming_g01_c291.avi',
#  'Action_v6/v_Grooming_g01_c285.avi',
#  'Action_v6/v_Pumping_g01_c44.avi',
#  'Action_v6/v_Feeding_g01_c117.avi',
#  'Action_v6/v_Pumping_g01_c78.avi',
#  'Action_v6/v_Feeding_g01_c103.avi',
#  'Action_v6/v_Grooming_g01_c252.avi',
#  'Action_v6/v_Pumping_g01_c93.avi',
#  'Action_v6/v_Pumping_g01_c87.avi',
#  'Action_v6/v_Grooming_g01_c246.avi',
#  'Action_v6/v_Grooming_g01_c247.avi',
#  'Action_v6/v_Pumping_g01_c86.avi',
#  'Action_v6/v_Pumping_g01_c92.avi',
#  'Action_v6/v_Grooming_g01_c253.avi',
#  'Action_v6/v_Feeding_g01_c102.avi',
#  'Action_v6/v_Pumping_g01_c64.avi',
#  'Action_v6/v_Pumping_g01_c70.avi',
#  'Action_v6/v_Feeding_g01_c61.avi',
#  ...]

# %%
def get_class(fname):
  """ Retrieve the name of the class given a filename.

    Args:
      fname: Name of the file in the UCF101 dataset.

    Returns:
      Class that the file belongs to.
  """
  return fname.split('_')[-3]
get_class(files[10])
# Out:
# 'Grooming'

# %%
def get_files_per_class(files):
  """ Retrieve the files that belong to each class.

    Args:
      files: List of files in the dataset.

    Returns:
      Dictionary of class names (key) and files (values).
  """
  files_for_class = collections.defaultdict(list)
  for fname in files:
    class_name = get_class(fname)
    files_for_class[class_name].append(fname)
  return files_for_class
get_files_per_class(files)
# Out:
# defaultdict(list,
#             {'Grooming': ['Action_v6/v_Grooming_g01_c326.avi',
#               'Action_v6/v_Grooming_g01_c332.avi',
#               'Action_v6/v_Grooming_g01_c124.avi',
#               'Action_v6/v_Grooming_g01_c130.avi',
#               'Action_v6/v_Grooming_g01_c118.avi',
#               'Action_v6/v_Grooming_g01_c36.avi',
#               'Action_v6/v_Grooming_g01_c22.avi',
#               'Action_v6/v_Grooming_g01_c291.avi',
#               'Action_v6/v_Grooming_g01_c285.avi',
#               'Action_v6/v_Grooming_g01_c252.avi',
#               'Action_v6/v_Grooming_g01_c246.avi',
#               'Action_v6/v_Grooming_g01_c247.avi',
#               'Action_v6/v_Grooming_g01_c253.avi',
#               'Action_v6/v_Grooming_g01_c284.avi',
#               'Action_v6/v_Grooming_g01_c290.avi',
#               'Action_v6/v_Grooming_g01_c23.avi',
#               'Action_v6/v_Grooming_g01_c119.avi',
#               'Action_v6/v_Grooming_g01_c37.avi',
#               'Action_v6/v_Grooming_g01_c131.avi',
#               'Action_v6/v_Grooming_g01_c125.avi',
#               'Action_v6/v_Grooming_g01_c333.avi',
#               'Action_v6/v_Grooming_g01_c327.avi',
#               'Action_v6/v_Grooming_g01_c331.avi',
#               'Action_v6/v_Grooming_g01_c325.avi',
#               'Action_v6/v_Grooming_g01_c319.avi',
#               'Action_v6/v_Grooming_g01_c133.avi',
#               'Action_v6/v_Grooming_g01_c127.avi',
#               'Action_v6/v_Grooming_g01_c21.avi',
#               'Action_v6/v_Grooming_g01_c35.avi',
#               'Action_v6/v_Grooming_g01_c286.avi',
#               'Action_v6/v_Grooming_g01_c292.avi',
#               'Action_v6/v_Grooming_g01_c245.avi',
#               'Action_v6/v_Grooming_g01_c251.avi',
#               'Action_v6/v_Grooming_g01_c279.avi',
#               'Action_v6/v_Grooming_g01_c278.avi',
#               'Action_v6/v_Grooming_g01_c250.avi',
#               'Action_v6/v_Grooming_g01_c244.avi',
#               'Action_v6/v_Grooming_g01_c293.avi',
#               'Action_v6/v_Grooming_g01_c287.avi',
#               'Action_v6/v_Grooming_g01_c34.avi',
#               'Action_v6/v_Grooming_g01_c20.avi',
#               'Action_v6/v_Grooming_g01_c126.avi',
#               'Action_v6/v_Grooming_g01_c132.avi',
#               'Action_v6/v_Grooming_g01_c318.avi',
#               'Action_v6/v_Grooming_g01_c324.avi',
#               'Action_v6/v_Pumping_g01_c128.avi',
#               'Action_v6/v_Pumping_g01_c5.avi',
#               'Action_v6/v_Pumping_g01_c114.avi',
#               'Action_v6/v_Pumping_g01_c100.avi'],
#              'Feeding': ['Action_v6/v_Feeding_g01_c249.avi',
#               'Action_v6/v_Feeding_g01_c261.avi',
#               'Action_v6/v_Feeding_g01_c275.avi',
#               'Action_v6/v_Feeding_g01_c329.avi',
#               'Action_v6/v_Feeding_g01_c315.avi',
#               'Action_v6/v_Feeding_g01_c96.avi',
#               'Action_v6/v_Feeding_g01_c82.avi',
#               'Action_v6/v_Feeding_g01_c301.avi',
#               'Action_v6/v_Feeding_g01_c69.avi',
#               'Action_v6/v_Feeding_g01_c55.avi',
#               'Action_v6/v_Feeding_g01_c41.avi',
#               'Action_v6/v_Feeding_g01_c117.avi',
#               'Action_v6/v_Feeding_g01_c103.avi',
#               'Action_v6/v_Feeding_g01_c102.avi',
#               'Action_v6/v_Feeding_g01_c116.avi',
#               'Action_v6/v_Feeding_g01_c40.avi',
#               'Action_v6/v_Feeding_g01_c54.avi',
#               'Action_v6/v_Feeding_g01_c68.avi',
#               'Action_v6/v_Feeding_g01_c83.avi',
#               'Action_v6/v_Feeding_g01_c300.avi',
#               'Action_v6/v_Feeding_g01_c314.avi',
#               'Action_v6/v_Feeding_g01_c97.avi',
#               'Action_v6/v_Feeding_g01_c328.avi',
#               'Action_v6/v_Feeding_g01_c274.avi',
#               'Action_v6/v_Feeding_g01_c260.avi',
#               'Action_v6/v_Feeding_g01_c248.avi',
#               'Action_v6/v_Feeding_g01_c276.avi',
#               'Action_v6/v_Feeding_g01_c262.avi',
#               'Action_v6/v_Feeding_g01_c289.avi',
#               'Action_v6/v_Feeding_g01_c302.avi',
#               'Action_v6/v_Feeding_g01_c81.avi',
#               'Action_v6/v_Feeding_g01_c95.avi',
#               'Action_v6/v_Feeding_g01_c316.avi',
#               'Action_v6/v_Feeding_g01_c42.avi',
#               'Action_v6/v_Feeding_g01_c56.avi',
#               'Action_v6/v_Feeding_g01_c128.avi',
#               'Action_v6/v_Feeding_g01_c100.avi',
#               'Action_v6/v_Feeding_g01_c114.avi',
#               'Action_v6/v_Feeding_g01_c115.avi',
#               'Action_v6/v_Feeding_g01_c101.avi',
#               'Action_v6/v_Feeding_g01_c129.avi',
#               'Action_v6/v_Feeding_g01_c57.avi',
#               'Action_v6/v_Feeding_g01_c43.avi',
#               'Action_v6/v_Feeding_g01_c94.avi',
#               'Action_v6/v_Feeding_g01_c317.avi',
#               'Action_v6/v_Feeding_g01_c303.avi',
#               'Action_v6/v_Feeding_g01_c80.avi',
#               'Action_v6/v_Feeding_g01_c288.avi',
#               'Action_v6/v_Feeding_g01_c263.avi',
#               'Action_v6/v_Feeding_g01_c277.avi',
#               'Action_v6/v_Feeding_g01_c273.avi',
#               'Action_v6/v_Feeding_g01_c267.avi',
#               'Action_v6/v_Feeding_g01_c298.avi',
#               'Action_v6/v_Feeding_g01_c84.avi',
#               'Action_v6/v_Feeding_g01_c307.avi',
#               'Action_v6/v_Feeding_g01_c313.avi',
#               'Action_v6/v_Feeding_g01_c90.avi',
#               'Action_v6/v_Feeding_g01_c47.avi',
#               'Action_v6/v_Feeding_g01_c53.avi',
#               'Action_v6/v_Feeding_g01_c105.avi',
#               'Action_v6/v_Feeding_g01_c111.avi',
#               'Action_v6/v_Feeding_g01_c139.avi',
#               'Action_v6/v_Feeding_g01_c138.avi',
#               'Action_v6/v_Feeding_g01_c110.avi',
#               'Action_v6/v_Feeding_g01_c104.avi',
#               'Action_v6/v_Feeding_g01_c52.avi',
#               'Action_v6/v_Feeding_g01_c46.avi',
#               'Action_v6/v_Feeding_g01_c312.avi',
#               'Action_v6/v_Feeding_g01_c91.avi',
#               'Action_v6/v_Feeding_g01_c85.avi',
#               'Action_v6/v_Feeding_g01_c306.avi',
#               'Action_v6/v_Feeding_g01_c299.avi',
#               'Action_v6/v_Feeding_g01_c266.avi',
#               'Action_v6/v_Feeding_g01_c272.avi',
#               'Action_v6/v_Feeding_g01_c264.avi',
#               'Action_v6/v_Feeding_g01_c270.avi',
#               'Action_v6/v_Feeding_g01_c258.avi',
#               'Action_v6/v_Feeding_g01_c93.avi',
#               'Action_v6/v_Feeding_g01_c310.avi',
#               'Action_v6/v_Feeding_g01_c304.avi',
#               'Action_v6/v_Feeding_g01_c87.avi',
#               'Action_v6/v_Feeding_g01_c338.avi',
#               'Action_v6/v_Feeding_g01_c50.avi',
#               'Action_v6/v_Feeding_g01_c44.avi',
#               'Action_v6/v_Feeding_g01_c78.avi',
#               'Action_v6/v_Feeding_g01_c112.avi',
#               'Action_v6/v_Feeding_g01_c106.avi',
#               'Action_v6/v_Feeding_g01_c107.avi',
#               'Action_v6/v_Feeding_g01_c113.avi',
#               'Action_v6/v_Feeding_g01_c79.avi',
#               'Action_v6/v_Feeding_g01_c45.avi',
#               'Action_v6/v_Feeding_g01_c51.avi',
#               'Action_v6/v_Feeding_g01_c339.avi',
#               'Action_v6/v_Feeding_g01_c305.avi',
#               'Action_v6/v_Feeding_g01_c86.avi',
#               'Action_v6/v_Feeding_g01_c92.avi',
#               'Action_v6/v_Feeding_g01_c311.avi',
#               'Action_v6/v_Feeding_g01_c259.avi',
#               'Action_v6/v_Feeding_g01_c271.avi',
#               'Action_v6/v_Feeding_g01_c265.avi',
#               'Action_v6/v_Feeding_g01_c202.avi',
#               'Action_v6/v_Feeding_g01_c216.avi',
#               'Action_v6/v_Feeding_g01_c410.avi',
#               'Action_v6/v_Feeding_g01_c376.avi',
#               'Action_v6/v_Feeding_g01_c362.avi',
#               'Action_v6/v_Feeding_g01_c404.avi',
#               'Action_v6/v_Feeding_g01_c389.avi',
#               'Action_v6/v_Feeding_g01_c36.avi',
#               'Action_v6/v_Feeding_g01_c22.avi',
#               'Action_v6/v_Feeding_g01_c148.avi',
#               'Action_v6/v_Feeding_g01_c3.avi',
#               'Action_v6/v_Feeding_g01_c174.avi',
#               'Action_v6/v_Feeding_g01_c160.avi',
#               'Action_v6/v_Feeding_g01_c161.avi',
#               'Action_v6/v_Feeding_g01_c175.avi',
#               'Action_v6/v_Feeding_g01_c149.avi',
#               'Action_v6/v_Feeding_g01_c2.avi',
#               'Action_v6/v_Feeding_g01_c23.avi',
#               'Action_v6/v_Feeding_g01_c37.avi',
#               'Action_v6/v_Feeding_g01_c388.avi',
#               'Action_v6/v_Feeding_g01_c363.avi',
#               'Action_v6/v_Feeding_g01_c405.avi',
#               'Action_v6/v_Feeding_g01_c411.avi',
#               'Action_v6/v_Feeding_g01_c377.avi',
#               'Action_v6/v_Feeding_g01_c217.avi',
#               'Action_v6/v_Feeding_g01_c203.avi',
#               'Action_v6/v_Feeding_g01_c229.avi',
#               'Action_v6/v_Feeding_g01_c215.avi',
#               'Action_v6/v_Feeding_g01_c201.avi',
#               'Action_v6/v_Feeding_g01_c349.avi',
#               'Action_v6/v_Feeding_g01_c407.avi',
#               'Action_v6/v_Feeding_g01_c361.avi',
#               'Action_v6/v_Feeding_g01_c375.avi',
#               'Action_v6/v_Feeding_g01_c21.avi',
#               'Action_v6/v_Feeding_g01_c35.avi',
#               'Action_v6/v_Feeding_g01_c0.avi',
#               'Action_v6/v_Feeding_g01_c163.avi',
#               'Action_v6/v_Feeding_g01_c177.avi',
#               'Action_v6/v_Feeding_g01_c188.avi',
#               'Action_v6/v_Feeding_g01_c189.avi',
#               'Action_v6/v_Feeding_g01_c176.avi',
#               'Action_v6/v_Feeding_g01_c162.avi',
#               'Action_v6/v_Feeding_g01_c1.avi',
#               'Action_v6/v_Feeding_g01_c34.avi',
#               'Action_v6/v_Feeding_g01_c20.avi',
#               'Action_v6/v_Feeding_g01_c374.avi',
#               'Action_v6/v_Feeding_g01_c406.avi',
#               'Action_v6/v_Feeding_g01_c360.avi',
#               'Action_v6/v_Feeding_g01_c348.avi',
#               'Action_v6/v_Feeding_g01_c200.avi',
#               'Action_v6/v_Feeding_g01_c214.avi',
#               'Action_v6/v_Feeding_g01_c228.avi',
#               'Action_v6/v_Feeding_g01_c210.avi',
#               'Action_v6/v_Feeding_g01_c204.avi',
#               'Action_v6/v_Feeding_g01_c238.avi',
#               'Action_v6/v_Feeding_g01_c364.avi',
#               'Action_v6/v_Feeding_g01_c402.avi',
#               'Action_v6/v_Feeding_g01_c370.avi',
#               'Action_v6/v_Feeding_g01_c358.avi',
#               'Action_v6/v_Feeding_g01_c24.avi',
#               'Action_v6/v_Feeding_g01_c30.avi',
#               'Action_v6/v_Feeding_g01_c18.avi',
#               'Action_v6/v_Feeding_g01_c166.avi',
#               'Action_v6/v_Feeding_g01_c172.avi',
#               'Action_v6/v_Feeding_g01_c5.avi',
#               'Action_v6/v_Feeding_g01_c199.avi',
#               'Action_v6/v_Feeding_g01_c198.avi',
#               'Action_v6/v_Feeding_g01_c4.avi',
#               'Action_v6/v_Feeding_g01_c173.avi',
#               'Action_v6/v_Feeding_g01_c167.avi',
#               'Action_v6/v_Feeding_g01_c19.avi',
#               'Action_v6/v_Feeding_g01_c31.avi',
#               'Action_v6/v_Feeding_g01_c25.avi',
#               'Action_v6/v_Feeding_g01_c359.avi',
#               'Action_v6/v_Feeding_g01_c371.avi',
#               'Action_v6/v_Feeding_g01_c365.avi',
#               'Action_v6/v_Feeding_g01_c403.avi',
#               'Action_v6/v_Feeding_g01_c239.avi',
#               'Action_v6/v_Feeding_g01_c205.avi',
#               'Action_v6/v_Feeding_g01_c211.avi',
#               'Action_v6/v_Feeding_g01_c207.avi',
#               'Action_v6/v_Feeding_g01_c213.avi',
#               'Action_v6/v_Feeding_g01_c373.avi',
#               'Action_v6/v_Feeding_g01_c401.avi',
#               'Action_v6/v_Feeding_g01_c367.avi',
#               'Action_v6/v_Feeding_g01_c33.avi',
#               'Action_v6/v_Feeding_g01_c27.avi',
#               'Action_v6/v_Feeding_g01_c398.avi',
#               'Action_v6/v_Feeding_g01_c171.avi',
#               'Action_v6/v_Feeding_g01_c165.avi',
#               'Action_v6/v_Feeding_g01_c6.avi',
#               'Action_v6/v_Feeding_g01_c159.avi',
#               'Action_v6/v_Feeding_g01_c158.avi',
#               'Action_v6/v_Feeding_g01_c7.avi',
#               'Action_v6/v_Feeding_g01_c164.avi',
#               'Action_v6/v_Feeding_g01_c170.avi',
#               'Action_v6/v_Feeding_g01_c399.avi',
#               'Action_v6/v_Feeding_g01_c26.avi',
#               'Action_v6/v_Feeding_g01_c32.avi',
#               'Action_v6/v_Feeding_g01_c400.avi',
#               'Action_v6/v_Feeding_g01_c366.avi',
#               'Action_v6/v_Feeding_g01_c372.avi',
#               'Action_v6/v_Feeding_g01_c212.avi',
#               'Action_v6/v_Feeding_g01_c206.avi',
#               'Action_v6/v_Feeding_g01_c223.avi',
#               'Action_v6/v_Feeding_g01_c237.avi',
#               'Action_v6/v_Feeding_g01_c357.avi',
#               'Action_v6/v_Feeding_g01_c343.avi',
#               'Action_v6/v_Feeding_g01_c17.avi',
#               'Action_v6/v_Feeding_g01_c394.avi',
#               'Action_v6/v_Feeding_g01_c380.avi',
#               'Action_v6/v_Feeding_g01_c169.avi',
#               'Action_v6/v_Feeding_g01_c155.avi',
#               'Action_v6/v_Feeding_g01_c141.avi',
#               'Action_v6/v_Feeding_g01_c196.avi',
#               'Action_v6/v_Feeding_g01_c182.avi',
#               'Action_v6/v_Feeding_g01_c183.avi',
#               'Action_v6/v_Feeding_g01_c197.avi',
#               'Action_v6/v_Feeding_g01_c140.avi',
#               'Action_v6/v_Feeding_g01_c154.avi',
#               'Action_v6/v_Feeding_g01_c168.avi',
#               'Action_v6/v_Feeding_g01_c381.avi',
#               'Action_v6/v_Feeding_g01_c16.avi',
#               'Action_v6/v_Feeding_g01_c395.avi',
#               'Action_v6/v_Feeding_g01_c342.avi',
#               'Action_v6/v_Feeding_g01_c356.avi',
#               'Action_v6/v_Feeding_g01_c236.avi',
#               'Action_v6/v_Feeding_g01_c222.avi',
#               'Action_v6/v_Feeding_g01_c208.avi',
#               'Action_v6/v_Feeding_g01_c234.avi',
#               'Action_v6/v_Feeding_g01_c220.avi',
#               'Action_v6/v_Feeding_g01_c368.avi',
#               'Action_v6/v_Feeding_g01_c340.avi',
#               'Action_v6/v_Feeding_g01_c354.avi',
#               'Action_v6/v_Feeding_g01_c28.avi',
#               'Action_v6/v_Feeding_g01_c383.avi',
#               'Action_v6/v_Feeding_g01_c397.avi',
#               'Action_v6/v_Feeding_g01_c14.avi',
#               'Action_v6/v_Feeding_g01_c142.avi',
#               'Action_v6/v_Feeding_g01_c9.avi',
#               'Action_v6/v_Feeding_g01_c156.avi',
#               'Action_v6/v_Feeding_g01_c181.avi',
#               'Action_v6/v_Feeding_g01_c195.avi',
#               'Action_v6/v_Feeding_g01_c194.avi',
#               'Action_v6/v_Feeding_g01_c180.avi',
#               'Action_v6/v_Feeding_g01_c157.avi',
#               'Action_v6/v_Feeding_g01_c143.avi',
#               'Action_v6/v_Feeding_g01_c8.avi',
#               'Action_v6/v_Feeding_g01_c396.avi',
#               'Action_v6/v_Feeding_g01_c15.avi',
#               'Action_v6/v_Feeding_g01_c382.avi',
#               'Action_v6/v_Feeding_g01_c29.avi',
#               'Action_v6/v_Feeding_g01_c355.avi',
#               'Action_v6/v_Feeding_g01_c341.avi',
#               'Action_v6/v_Feeding_g01_c369.avi',
#               'Action_v6/v_Feeding_g01_c221.avi',
#               'Action_v6/v_Feeding_g01_c235.avi',
#               'Action_v6/v_Feeding_g01_c209.avi',
#               'Action_v6/v_Feeding_g01_c231.avi',
#               'Action_v6/v_Feeding_g01_c225.avi',
#               'Action_v6/v_Feeding_g01_c219.avi',
#               'Action_v6/v_Feeding_g01_c345.avi',
#               'Action_v6/v_Feeding_g01_c351.avi',
#               'Action_v6/v_Feeding_g01_c379.avi',
#               'Action_v6/v_Feeding_g01_c386.avi',
#               'Action_v6/v_Feeding_g01_c11.avi',
#               'Action_v6/v_Feeding_g01_c392.avi',
#               'Action_v6/v_Feeding_g01_c39.avi',
#               'Action_v6/v_Feeding_g01_c147.avi',
#               'Action_v6/v_Feeding_g01_c153.avi',
#               'Action_v6/v_Feeding_g01_c184.avi',
#               'Action_v6/v_Feeding_g01_c190.avi',
#               'Action_v6/v_Feeding_g01_c191.avi',
#               'Action_v6/v_Feeding_g01_c185.avi',
#               'Action_v6/v_Feeding_g01_c152.avi',
#               'Action_v6/v_Feeding_g01_c146.avi',
#               'Action_v6/v_Feeding_g01_c38.avi',
#               'Action_v6/v_Feeding_g01_c10.avi',
#               'Action_v6/v_Feeding_g01_c393.avi',
#               'Action_v6/v_Feeding_g01_c387.avi',
#               'Action_v6/v_Feeding_g01_c378.avi',
#               'Action_v6/v_Feeding_g01_c350.avi',
#               'Action_v6/v_Feeding_g01_c344.avi',
#               'Action_v6/v_Feeding_g01_c218.avi',
#               'Action_v6/v_Feeding_g01_c224.avi',
#               'Action_v6/v_Feeding_g01_c230.avi',
#               'Action_v6/v_Feeding_g01_c226.avi',
#               'Action_v6/v_Feeding_g01_c232.avi',
#               'Action_v6/v_Feeding_g01_c352.avi',
#               'Action_v6/v_Feeding_g01_c346.avi',
#               'Action_v6/v_Feeding_g01_c408.avi',
#               'Action_v6/v_Feeding_g01_c391.avi',
#               'Action_v6/v_Feeding_g01_c12.avi',
#               'Action_v6/v_Feeding_g01_c385.avi',
#               'Action_v6/v_Feeding_g01_c150.avi',
#               'Action_v6/v_Feeding_g01_c144.avi',
#               'Action_v6/v_Feeding_g01_c178.avi',
#               'Action_v6/v_Feeding_g01_c193.avi',
#               'Action_v6/v_Feeding_g01_c187.avi',
#               'Action_v6/v_Feeding_g01_c186.avi',
#               'Action_v6/v_Feeding_g01_c192.avi',
#               'Action_v6/v_Feeding_g01_c179.avi',
#               'Action_v6/v_Feeding_g01_c145.avi',
#               'Action_v6/v_Feeding_g01_c151.avi',
#               'Action_v6/v_Feeding_g01_c384.avi',
#               'Action_v6/v_Feeding_g01_c390.avi',
#               'Action_v6/v_Feeding_g01_c13.avi',
#               'Action_v6/v_Feeding_g01_c409.avi',
#               'Action_v6/v_Feeding_g01_c347.avi',
#               'Action_v6/v_Feeding_g01_c353.avi',
#               'Action_v6/v_Feeding_g01_c233.avi',
#               'Action_v6/v_Feeding_g01_c227.avi',
#               'Action_v6/v_Feeding_g01_c268.avi',
#               'Action_v6/v_Feeding_g01_c240.avi',
#               'Action_v6/v_Feeding_g01_c254.avi',
#               'Action_v6/v_Feeding_g01_c283.avi',
#               'Action_v6/v_Feeding_g01_c297.avi',
#               'Action_v6/v_Feeding_g01_c308.avi',
#               'Action_v6/v_Feeding_g01_c334.avi',
#               'Action_v6/v_Feeding_g01_c320.avi',
#               'Action_v6/v_Feeding_g01_c48.avi',
#               'Action_v6/v_Feeding_g01_c74.avi',
#               'Action_v6/v_Feeding_g01_c60.avi',
#               'Action_v6/v_Feeding_g01_c136.avi',
#               'Action_v6/v_Feeding_g01_c122.avi',
#               'Action_v6/v_Feeding_g01_c123.avi',
#               'Action_v6/v_Feeding_g01_c137.avi',
#               'Action_v6/v_Feeding_g01_c61.avi',
#               'Action_v6/v_Feeding_g01_c75.avi',
#               'Action_v6/v_Feeding_g01_c49.avi',
#               'Action_v6/v_Feeding_g01_c321.avi',
#               'Action_v6/v_Feeding_g01_c335.avi',
#               'Action_v6/v_Feeding_g01_c309.avi',
#               'Action_v6/v_Feeding_g01_c296.avi',
#               'Action_v6/v_Feeding_g01_c282.avi',
#               'Action_v6/v_Feeding_g01_c255.avi',
#               'Action_v6/v_Feeding_g01_c241.avi',
#               'Action_v6/v_Feeding_g01_c269.avi',
#               'Action_v6/v_Feeding_g01_c257.avi',
#               'Action_v6/v_Feeding_g01_c243.avi',
#               'Action_v6/v_Feeding_g01_c294.avi',
#               'Action_v6/v_Feeding_g01_c280.avi',
#               'Action_v6/v_Feeding_g01_c88.avi',
#               'Action_v6/v_Feeding_g01_c323.avi',
#               'Action_v6/v_Feeding_g01_c337.avi',
#               'Action_v6/v_Feeding_g01_c63.avi',
#               'Action_v6/v_Feeding_g01_c77.avi',
#               'Action_v6/v_Feeding_g01_c109.avi',
#               'Action_v6/v_Feeding_g01_c121.avi',
#               'Action_v6/v_Feeding_g01_c135.avi',
#               'Action_v6/v_Feeding_g01_c134.avi',
#               'Action_v6/v_Feeding_g01_c120.avi',
#               'Action_v6/v_Feeding_g01_c108.avi',
#               'Action_v6/v_Feeding_g01_c76.avi',
#               'Action_v6/v_Feeding_g01_c62.avi',
#               'Action_v6/v_Feeding_g01_c336.avi',
#               'Action_v6/v_Feeding_g01_c322.avi',
#               'Action_v6/v_Feeding_g01_c89.avi',
#               'Action_v6/v_Feeding_g01_c281.avi',
#               'Action_v6/v_Feeding_g01_c295.avi',
#               'Action_v6/v_Feeding_g01_c242.avi',
#               'Action_v6/v_Feeding_g01_c256.avi',
#               'Action_v6/v_Feeding_g01_c252.avi',
#               'Action_v6/v_Feeding_g01_c246.avi',
#               'Action_v6/v_Feeding_g01_c291.avi',
#               'Action_v6/v_Feeding_g01_c285.avi',
#               'Action_v6/v_Feeding_g01_c326.avi',
#               'Action_v6/v_Feeding_g01_c332.avi',
#               'Action_v6/v_Feeding_g01_c99.avi',
#               'Action_v6/v_Feeding_g01_c66.avi',
#               'Action_v6/v_Feeding_g01_c72.avi',
#               'Action_v6/v_Feeding_g01_c124.avi',
#               'Action_v6/v_Feeding_g01_c130.avi',
#               'Action_v6/v_Feeding_g01_c118.avi',
#               'Action_v6/v_Feeding_g01_c119.avi',
#               'Action_v6/v_Feeding_g01_c131.avi',
#               'Action_v6/v_Feeding_g01_c125.avi',
#               'Action_v6/v_Feeding_g01_c73.avi',
#               'Action_v6/v_Feeding_g01_c67.avi',
#               'Action_v6/v_Feeding_g01_c98.avi',
#               'Action_v6/v_Feeding_g01_c333.avi',
#               'Action_v6/v_Feeding_g01_c327.avi',
#               'Action_v6/v_Feeding_g01_c284.avi',
#               'Action_v6/v_Feeding_g01_c290.avi',
#               'Action_v6/v_Feeding_g01_c247.avi',
#               'Action_v6/v_Feeding_g01_c253.avi',
#               'Action_v6/v_Feeding_g01_c245.avi',
#               'Action_v6/v_Feeding_g01_c251.avi',
#               'Action_v6/v_Feeding_g01_c279.avi',
#               'Action_v6/v_Feeding_g01_c286.avi',
#               'Action_v6/v_Feeding_g01_c292.avi',
#               'Action_v6/v_Feeding_g01_c331.avi',
#               'Action_v6/v_Feeding_g01_c325.avi',
#               'Action_v6/v_Feeding_g01_c319.avi',
#               'Action_v6/v_Feeding_g01_c71.avi',
#               'Action_v6/v_Feeding_g01_c65.avi',
#               'Action_v6/v_Feeding_g01_c59.avi',
#               'Action_v6/v_Feeding_g01_c133.avi',
#               'Action_v6/v_Feeding_g01_c127.avi',
#               'Action_v6/v_Feeding_g01_c126.avi',
#               'Action_v6/v_Feeding_g01_c132.avi',
#               'Action_v6/v_Feeding_g01_c58.avi',
#               'Action_v6/v_Feeding_g01_c64.avi',
#               'Action_v6/v_Feeding_g01_c70.avi',
#               'Action_v6/v_Feeding_g01_c318.avi',
#               'Action_v6/v_Feeding_g01_c324.avi',
#               'Action_v6/v_Feeding_g01_c330.avi',
#               'Action_v6/v_Feeding_g01_c293.avi',
#               'Action_v6/v_Feeding_g01_c287.avi',
#               'Action_v6/v_Feeding_g01_c278.avi',
#               'Action_v6/v_Feeding_g01_c250.avi',
#               'Action_v6/v_Feeding_g01_c244.avi']})

# %%
NUM_CLASSES = 3
FILES_PER_CLASS = 412
files_for_class = get_files_per_class(files)
classes = list(files_for_class.keys())

# %%
print('Num classes:', len(classes))
print('Num videos for class[0]:', len(files_for_class[classes[2]]))
# Out:
# Num classes: 3
# Num videos for class[0]: 412

# %%
def select_subset_of_classes(files_for_class, classes, files_per_class):
  """ Create a dictionary with the class name and a subset of the files in that class.

    Args:
      files_for_class: Dictionary of class names (key) and files (values).
      classes: List of classes.
      files_per_class: Number of files per class of interest.

    Returns:
      Dictionary with class as key and list of specified number of video files in that class.
  """
  files_subset = dict()

  for class_name in classes:
    class_files = files_for_class[class_name]
    files_subset[class_name] = class_files[:files_per_class]

  return files_subset

# %%
files_subset = select_subset_of_classes(files_for_class, classes[:NUM_CLASSES], FILES_PER_CLASS)
list(files_subset.keys())
# Out:
# ['Grooming', 'Pumping', 'Feeding']

# %%
def download_from_zip(zip_url, to_dir, file_names):
  """ Download the contents of the zip file from the zip URL.

    Args:
      zip_url: A URL with a zip file containing data.
      to_dir: A directory to download data to.
      file_names: Names of files to download.
  """
  with rz.RemoteZip(zip_url) as zip:
    for fn in tqdm.tqdm(file_names):
      class_name = get_class(fn)
      zip.extract(fn, str(to_dir / class_name))
      unzipped_file = to_dir / class_name / fn

      fn = pathlib.Path(fn).parts[-1]
      output_file = to_dir / class_name / fn
      unzipped_file.rename(output_file)

# %%
def split_class_lists(files_for_class, count):
  """ Returns the list of files belonging to a subset of data as well as the remainder of
    files that need to be downloaded.

    Args:
      files_for_class: Files belonging to a particular class of data.
      count: Number of files to download.

    Returns:
      Files belonging to the subset of data and dictionary of the remainder of files that need to be downloaded.
  """
  split_files = []
  remainder = {}
  for cls in files_for_class:
    split_files.extend(files_for_class[cls][:count])
    remainder[cls] = files_for_class[cls][count:]
  return split_files, remainder

# %%
def download_ufc_101_subset(zip_url, num_classes, splits, download_dir):
  """ Download a subset of the UFC101 dataset and split them into various parts, such as
    training, validation, and test.

    Args:
      zip_url: A URL with a ZIP file with the data.
      num_classes: Number of labels.
      splits: Dictionary specifying the training, validation, test, etc. (key) division of data
              (value is number of files per split).
      download_dir: Directory to download data to.

    Return:
      Mapping of the directories containing the subsections of data.
  """
  files = list_files_from_zip_url(zip_url)
  files.remove(files[0])
  counter=0
  print(len(files))

  files_for_class = get_files_per_class(files)
  print(len(files_for_class['Pumping']))

  classes = list(files_for_class.keys())[:num_classes]
  for cls in classes:
    random.shuffle(files_for_class[cls])

  # Only use the number of classes you want in the dictionary
  files_for_class = {x: files_for_class[x] for x in classes}
  print(files_for_class)
  print(len(files_for_class['Pumping']))

  dirs = {}

  for split_name, split_count in splits.items():
     print(split_name, ":")
     split_dir = download_dir / split_name
     split_files, files_for_class = split_class_lists(files_for_class, split_count)

     print(split_name, len(split_files))
     download_from_zip(zip_url, split_dir, split_files)
     dirs[split_name] = split_dir

  return dirs

# %% [markdown]
# # Download

# %%
download_dir = pathlib.Path('./Action_subset/')
subset_paths = download_ufc_101_subset(URL,
                                       num_classes = 3,
                                       splits = {"train": 247, "test": 165},
                                       download_dir = download_dir)
# Out:
# 1236
_v6/v_Grooming_g01_c71.avi', 'Action_v6/v_Grooming_g01_c368.avi', 'Action_v6/v_Grooming_g01_c163.avi', 'Action_v6/v_Grooming_g01_c133.avi', 'Action_v6/v_Grooming_g01_c60.avi', 'Action_v6/v_Grooming_g01_c99.avi', 'Action_v6/v_Grooming_g01_c328.avi', 'Action_v6/v_Grooming_g01_c91.avi', 'Action_v6/v_Grooming_g01_c179.avi', 'Action_v6/v_Grooming_g01_c159.avi', 'Action_v6/v_Grooming_g01_c326.avi', 'Action_v6/v_Grooming_g01_c190.avi', 'Action_v6/v_Grooming_g01_c396.avi', 'Action_v6/v_Grooming_g01_c324.avi', 'Action_v6/v_Grooming_g01_c310.avi', 'Action_v6/v_Grooming_g01_c227.avi', 'Action_v6/v_Grooming_g01_c81.avi', 'Action_v6/v_Grooming_g01_c108.avi', 'Action_v6/v_Grooming_g01_c318.avi', 'Action_v6/v_Grooming_g01_c385.avi', 'Action_v6/v_Grooming_g01_c74.avi', 'Action_v6/v_Grooming_g01_c268.avi', 'Action_v6/v_Grooming_g01_c274.avi', 'Action_v6/v_Grooming_g01_c321.avi', 'Action_v6/v_Grooming_g01_c229.avi', 'Action_v6/v_Grooming_g01_c261.avi', 'Action_v6/v_Grooming_g01_c299.avi', 'Action_v6/v_Grooming_g01_c217.avi', 'Action_v6/v_Grooming_g01_c323.avi', 'Action_v6/v_Grooming_g01_c234.avi', 'Action_v6/v_Grooming_g01_c258.avi', 'Action_v6/v_Grooming_g01_c404.avi', 'Action_v6/v_Grooming_g01_c121.avi', 'Action_v6/v_Grooming_g01_c399.avi', 'Action_v6/v_Grooming_g01_c209.avi', 'Action_v6/v_Grooming_g01_c287.avi', 'Action_v6/v_Grooming_g01_c202.avi', 'Action_v6/v_Grooming_g01_c97.avi', 'Action_v6/v_Grooming_g01_c135.avi', 'Action_v6/v_Grooming_g01_c142.avi', 'Action_v6/v_Grooming_g01_c8.avi', 'Action_v6/v_Grooming_g01_c231.avi', 'Action_v6/v_Grooming_g01_c348.avi', 'Action_v6/v_Grooming_g01_c225.avi', 'Action_v6/v_G ...
# 412
# train :
# train 741
# 100%|██████████| 741/741 [01:57<00:00,  6.30it/s]
# test :
# test 495
# 100%|██████████| 495/495 [01:18<00:00,  6.29it/s]

# %% [markdown]
# # Frames

# %%
def format_frames(frame, output_size):
  """
    Pad and resize an image from a video.

    Args:
      frame: Image that needs to resized and padded.
      output_size: Pixel size of the output frame image.

    Return:
      Formatted frame with padding of specified output size.
  """
  frame = tf.image.convert_image_dtype(frame, tf.float32)
  frame = tf.image.resize_with_pad(frame, *output_size)
  return frame

def frames_from_video_file(video_path, n_frames, output_size = (224,224), frame_step = 15):
  """
    Creates frames from each video file present for each category.

    Args:
      video_path: File path to the video.
      n_frames: Number of frames to be created per video file.
      output_size: Pixel size of the output frame image.

    Return:
      An NumPy array of frames in the shape of (n_frames, height, width, channels).
  """
  # Read each video frame by frame
  result = []
  src = cv2.VideoCapture(str(video_path))

  video_length = src.get(cv2.CAP_PROP_FRAME_COUNT)

  need_length = 1 + (n_frames - 1) * frame_step

  if need_length > video_length:
    start = 0
  else:
    max_start = video_length - need_length
    start = random.randint(0, max_start + 1)

  src.set(cv2.CAP_PROP_POS_FRAMES, start)
  # ret is a boolean indicating whether read was successful, frame is the image itself
  ret, frame = src.read()
  result.append(format_frames(frame, output_size))

  for _ in range(n_frames - 1):
    for _ in range(frame_step):
      ret, frame = src.read()
    if ret:
      frame = format_frames(frame, output_size)
      result.append(frame)
    else:
      result.append(np.zeros_like(result[0]))
  src.release()
  result = np.array(result)[..., [2, 1, 0]]

  return result

class FrameGenerator:
  def __init__(self, path, n_frames, training = False):
    """ Returns a set of frames with their associated label.

      Args:
        path: Video file paths.
        n_frames: Number of frames.
        training: Boolean to determine if training dataset is being created.
    """
    self.path = path
    self.n_frames = n_frames
    self.training = training
    self.class_names = sorted(set(p.name for p in self.path.iterdir() if p.is_dir()))
    self.class_ids_for_name = dict((name, idx) for idx, name in enumerate(self.class_names))

  def get_files_and_class_names(self):
    video_paths = list(self.path.glob('*/*.avi'))
    classes = [p.parent.name for p in video_paths]
    return video_paths, classes

  def __call__(self):
    video_paths, classes = self.get_files_and_class_names()

    pairs = list(zip(video_paths, classes))

    if self.training:
      random.shuffle(pairs)

    for path, name in pairs:
      video_frames = frames_from_video_file(path, self.n_frames)
      label = self.class_ids_for_name[name] # Encode labels
      yield video_frames, label

# %%
fg = FrameGenerator(subset_paths['train'], 10, training=True)

frames, label = next(fg())

print(f"Shape: {frames.shape}")
print(f"Label: {label}")
# Out:
# Shape: (10, 224, 224, 3)
# Label: 0

# %% [markdown]
# # Transfer Learning

# %%
batch_size = 8
num_frames = 8

output_signature = (tf.TensorSpec(shape = (None, None, None, 3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))

train_ds = tf.data.Dataset.from_generator(FrameGenerator(subset_paths['train'], num_frames, training = True),
                                          output_signature = output_signature)
train_ds = train_ds.batch(batch_size)

test_ds = tf.data.Dataset.from_generator(FrameGenerator(subset_paths['test'], num_frames),
                                         output_signature = output_signature)
test_ds = test_ds.batch(batch_size)

# %%
for frames, labels in train_ds.take(10):
  print(labels)
# Out:
# tf.Tensor([0 1 2 0 2 0 1 2], shape=(8,), dtype=int16)
# tf.Tensor([2 2 2 2 1 1 1 1], shape=(8,), dtype=int16)
# tf.Tensor([1 1 0 2 1 1 2 1], shape=(8,), dtype=int16)
# tf.Tensor([0 0 0 2 1 2 2 0], shape=(8,), dtype=int16)
# tf.Tensor([2 2 1 1 0 2 1 1], shape=(8,), dtype=int16)
# tf.Tensor([0 0 0 1 0 2 0 2], shape=(8,), dtype=int16)
# tf.Tensor([2 1 0 0 2 0 2 1], shape=(8,), dtype=int16)
# tf.Tensor([2 2 0 1 2 2 2 1], shape=(8,), dtype=int16)
# tf.Tensor([2 2 0 2 0 2 2 0], shape=(8,), dtype=int16)
# tf.Tensor([2 0 1 0 0 2 1 2], shape=(8,), dtype=int16)

# %%
print(f"Shape: {frames.shape}")
print(f"Label: {labels.shape}")
# Out:
# Shape: (8, 8, 224, 224, 3)
# Label: (8,)

# %%
gru = layers.GRU(units=4, return_sequences=True, return_state=True)

inputs = tf.random.normal(shape=[1, 10, 8]) # (batch, sequence, channels)

result, state = gru(inputs) # Run it all at once

# %%
first_half, state = gru(inputs[:, :5, :])   # run the first half, and capture the state
second_half, _ = gru(inputs[:,5:, :], initial_state=state)  # Use the state to continue where you left off.

print(np.allclose(result[:, :5,:], first_half))
print(np.allclose(result[:, 5:,:], second_half))
# Out:
# True
# True

# %%
model_id = 'a0'
resolution = 224

tf.keras.backend.clear_session()

backbone = movinet.Movinet(model_id=model_id)
backbone.trainable = True

# Set num_classes=600 to load the pre-trained weights from the original model
num_classes = 600  # Replace 10 with the actual number of action classes in your dataset
model = movinet_model.MovinetClassifier(backbone=backbone, num_classes=num_classes)
model.build([None, None, None, None, 3])

# Load pre-trained weights
# !wget https://storage.googleapis.com/tf_model_garden/vision/movinet/movinet_a0_base.tar.gz -O movinet_a0_base.tar.gz -q
# !tar -xvf movinet_a0_base.tar.gz

checkpoint_dir = f'movinet_{model_id}_base'
checkpoint_path = tf.train.latest_checkpoint(checkpoint_dir)
checkpoint = tf.train.Checkpoint(model=model)
status = checkpoint.restore(checkpoint_path)
status.assert_existing_objects_matched()
# Out:
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# WARNING:tensorflow:`tf.keras.layers.experimental.SyncBatchNormalization` endpoint is deprecated and will be removed in a future release. Please use `tf.keras.layers.BatchNormalization` with parameter `synchronized` set to True.
# movinet_a0_base/
# movinet_a0_base/checkpoint
# movinet_a0_base/ckpt-1.data-00000-of-00001
# movinet_a0_base/ckpt-1.index

# %%
def build_classifier(batch_size, num_frames, resolution, backbone, num_classes):
  """Builds a classifier on top of a backbone model."""
  model = movinet_model.MovinetClassifier(
      backbone=backbone,
      num_classes=num_classes)
  model.build([batch_size, num_frames, resolution, resolution, 3])

  return model

# %%
model = build_classifier(batch_size, num_frames, resolution, backbone, 3)

# %%
num_epochs = 4

loss_obj = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001)

model.compile(loss=loss_obj, optimizer=optimizer, metrics=['accuracy'])

# %%
results = model.fit(train_ds,
                    validation_data=test_ds,
                    epochs=num_epochs,
                    validation_freq=1,
                    verbose=1)
# Out:
# Epoch 1/4
# 93/93 [==============================] - 529s 5s/step - loss: 0.8623 - accuracy: 0.7679 - val_loss: 0.7181 - val_accuracy: 0.7960
# Epoch 2/4
# 93/93 [==============================] - 411s 4s/step - loss: 0.3652 - accuracy: 0.8880 - val_loss: 0.3610 - val_accuracy: 0.8525
# Epoch 3/4
# 93/93 [==============================] - 405s 4s/step - loss: 0.3879 - accuracy: 0.8718 - val_loss: 0.4004 - val_accuracy: 0.9313
# Epoch 4/4
# 93/93 [==============================] - 400s 4s/step - loss: 0.3210 - accuracy: 0.9055 - val_loss: 0.2648 - val_accuracy: 0.9434

# %%
model.evaluate(test_ds, return_dict=True)

# %%
while True:pass

# %% [markdown]
# # Streaming Model - Pt.2 Alternative

# %%
model_id = 'a2'
mode = 'stream'
version = '3'
hub_url = f'https://tfhub.dev/tensorflow/movinet/{model_id}/{mode}/kinetics-600/classification/{version}'
model = hub.load(hub_url)

# %%
num_epochs = 2

loss_obj = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)

optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001)

model.compile(loss=loss_obj, optimizer=optimizer, metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-0c295092a661> in <cell line: 7>()
#       5 optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001)
#       6
# ----> 7 model.compile(loss=loss_obj, optimizer=optimizer, metrics=['accuracy'])
#
# AttributeError: '_UserObject' object has no attribute 'compile'
